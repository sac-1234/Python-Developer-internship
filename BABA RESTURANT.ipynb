# %%
print('*'*120)
print('-'*120)

print("BABA KA DHABA ".center(77))

print('-'*120)
print('*'*120)
def dine():
    price=0
    print('enter no of veg packet')
    price=price+80*int(input())
    print('enter no of non-veg packet')
    price=price+160*int(input())
    bill(price,0)
def delivery():
    price=0
    print('enter no of veg packet')
    price=price+80*int(input())
    print('enter no of non-veg packet')
    price=price+160*int(input())
    km=float(input('enter Delivery distance in kms'))
    if km>0:
        if km <3:
            deli=0
        elif km>=3 and km<5:
            deli=5*km
        elif km>=5 and km<7:
            deli=7*km
        elif km>=7 and km<10:
            deli=10*km
        else:
            deli=15*km
    bill(price,deli)
def bill(price,deli):
    gst=price*.07
    total=price+gst+deli
    print(f"""Bill Summary-->>>
    Food Cost     -->>       {price}
    Delivery cost -->>       {deli}
    Gst           -->>        {gst}
    
    Total bill---->>     {total}
    
    Thank for visit .. See You Again
    {'*'*120}
    {'-'*120}
    
     """.center(77))
deli=0
price=0
while True:
    print('enter 1 for dine in') 
    print('enter 2 for Delivery')
    print('enter 3 for Exit')
    n=int(input())
    if n==1:
        dine()
        break
    elif n==2:
        delivery()
        break
    elif n==3:
        break
    else:
        print('Invalid Input')
# Out:
# ************************************************************************************************************************
# ------------------------------------------------------------------------------------------------------------------------
#                                 BABA KA DHABA
# ------------------------------------------------------------------------------------------------------------------------
# ************************************************************************************************************************
# enter 1 for dine in
# enter 2 for Delivery
# enter 3 for Exit
# 2
# enter no of veg packet
# 5
# enter no of non-veg packet
# 0
# enter Delivery distance in kms120
# Bill Summary-->>>
#     Food Cost     -->>       400
#     Delivery cost -->>       1800.0
#     Gst           -->>        28.000000000000004
#
#     Total bill---->>     2228.0
#
#     Thank for visit .. See You Again
# ...
